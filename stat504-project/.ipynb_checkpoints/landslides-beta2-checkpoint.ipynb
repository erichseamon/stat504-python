# %%
import matplotlib
# %matplotlib nbagg

from pyproj import Proj
from pandas import DataFrame
import pandas as pd


from urllib2 import Request, urlopen
import json
from pandas.io.json import json_normalize

request=Request('http://www.oregongeology.org/arcgis/rest/services/Public/SLIDO_3_2_Historic_Points/MapServer/0/query?where=OBJECTID_1+%3E+0&text=&objectIds=&time=&geometry=&geometryType=esriGeometryPoint&inSR=&spatialRel=esriSpatialRelIntersects&relationParam=&outFields=OBJECTID_1%2C+Shape%2C+REF_ID_COD%2C+UNIQUE_ID%2C+DATA_SOURC%2C+LOC_METHOD%2C+ORIG_ID%2C+SLIDE_NAME%2C+DATE%2C+LENGTH_ft%2C+WIDTH_ft%2C+DEPTH_ft%2C+SLOPE%2C+TYPE_MOVE%2C+MOVE_CLASS%2C+CONTR_FACT%2C+TYPE_MTRL%2C+AREA_ft2%2C+VOLUME_ft3%2C+DEEP_SHAL%2C+DAMAGES%2C+LOSSES%2C+COMMENTS%2C+Annual_Cos%2C+Repair_Cos&returnGeometry=false&returnTrueCurves=false&maxAllowableOffset=&geometryPrecision=&outSR=&returnIdsOnly=false&returnCountOnly=false&orderByFields=&groupByFieldsForStatistics=&outStatistics=&returnZ=false&returnM=false&gdbVersion=&returnDistinctValues=false&resultOffset=&resultRecordCount=&f=pjson')
response = urlopen(request)
elevations = response.read()
data = json.loads(elevations)
landslides = json_normalize(data[u'features'])

# %%
landslides.columns = ['AREA_ft2', 'Annual_Cos','COMMENTS', 'CONTR_FACT', 'DAMAGES','DATA_SOURC', 'DATE', 'DEEP_SHAL','DEPTH_ft', 'LENGTH_ft','LOC_METHOD', 'LOSSES','MOVE_CLASS', 'OBJECTID_1','ORIG_ID', 'REF_ID_COD','Repair_Cos', 'SLIDE_NAME', 'SLOPE','TYPE_MOVE', 'TYPE_MTRL','UNIQUE_ID', 'VOLUME_ft3','WIDTH_ft', 'x', 'y']

# %%
from pyproj import Proj, transform

inProj = Proj(init='epsg:3857')
outProj = Proj(init='epsg:4326')
lat = np.array(landslides.x)
lon = np.array(landslides.y)
x2,y2 = transform(inProj,outProj,lat,lon)
#print x2,y2

# %%
landslide_latlon = DataFrame(np.c_[y2, x2], columns=['Lat', 'Lon'])

# %%
landslides_new = pd.concat([landslides, landslide_latlon], axis=1)

# %%
#print landslides_new

# %%
from mpl_toolkits.basemap import Basemap
import matplotlib.pyplot as plt
import numpy as np

#my_map = Basemap(projection='ortho',lon_0=-105,lat_0=40,resolution='l')

# make sure the value of resolution is a lowercase L,
#  for 'low', not a numeral 1
#my_map = Basemap(projection='ortho', lat_0=50, lon_0=-100,
#             resolution='l', area_thresh=500)

my_map = Basemap(llcrnrlon=-125, llcrnrlat=41, urcrnrlon=-115,
     urcrnrlat=47, projection='tmerc', lat_1=33, lat_2=45,
     lon_0=-119, lat_0=45, resolution='h', area_thresh=10000)

my_map.drawcoastlines()
my_map.drawcountries()
my_map.fillcontinents(color='coral')

lon = np.array(landslides_new.Lon)
lat = np.array(landslides_new.Lat)
y,x = my_map(lon, lat)
my_map.plot(y,x, 'ro', markersize=4)

plt.show()
# Out:
# <img src="data:image/png;base64,...">

# %%
request=Request('http://www.oregongeology.org/arcgis/rest/services/Public/SLIDO_3_2_Historic_Points/MapServer/0/query?where=OBJECTID_1%3E0+and+OBJECTID_1%3E1000&text=&objectIds=&time=&geometry=&geometryType=esriGeometryPoint&inSR=&spatialRel=esriSpatialRelIntersects&relationParam=&outFields=OBJECTID_1%2C+Shape%2C+REF_ID_COD%2C+UNIQUE_ID%2C+DATA_SOURC%2C+LOC_METHOD%2C+ORIG_ID%2C+SLIDE_NAME%2C+DATE%2C+LENGTH_ft%2C+WIDTH_ft%2C+DEPTH_ft%2C+SLOPE%2C+TYPE_MOVE%2C+MOVE_CLASS%2C+CONTR_FACT%2C+TYPE_MTRL%2C+AREA_ft2%2C+VOLUME_ft3%2C+DEEP_SHAL%2C+DAMAGES%2C+LOSSES%2C+COMMENTS%2C+Annual_Cos%2C+Repair_Cos&returnGeometry=false&returnTrueCurves=false&maxAllowableOffset=&geometryPrecision=&outSR=&returnIdsOnly=false&returnCountOnly=false&orderByFields=&groupByFieldsForStatistics=&outStatistics=&returnZ=false&returnM=false&gdbVersion=&returnDistinctValues=false&resultOffset=&resultRecordCount=&f=pjson')
response = urlopen(request)
elevations = response.read()
data = json.loads(elevations)
landslides1 = json_normalize(data[u'features'])

request=Request('http://www.oregongeology.org/arcgis/rest/services/Public/SLIDO_3_2_Historic_Points/MapServer/0/query?where=OBJECTID_1%3E1001+and+OBJECTID_1%3E2000&text=&objectIds=&time=&geometry=&geometryType=esriGeometryPoint&inSR=&spatialRel=esriSpatialRelIntersects&relationParam=&outFields=OBJECTID_1%2C+Shape%2C+REF_ID_COD%2C+UNIQUE_ID%2C+DATA_SOURC%2C+LOC_METHOD%2C+ORIG_ID%2C+SLIDE_NAME%2C+DATE%2C+LENGTH_ft%2C+WIDTH_ft%2C+DEPTH_ft%2C+SLOPE%2C+TYPE_MOVE%2C+MOVE_CLASS%2C+CONTR_FACT%2C+TYPE_MTRL%2C+AREA_ft2%2C+VOLUME_ft3%2C+DEEP_SHAL%2C+DAMAGES%2C+LOSSES%2C+COMMENTS%2C+Annual_Cos%2C+Repair_Cos&returnGeometry=false&returnTrueCurves=false&maxAllowableOffset=&geometryPrecision=&outSR=&returnIdsOnly=false&returnCountOnly=false&orderByFields=&groupByFieldsForStatistics=&outStatistics=&returnZ=false&returnM=false&gdbVersion=&returnDistinctValues=false&resultOffset=&resultRecordCount=&f=pjson')
response = urlopen(request)
elevations = response.read()
data = json.loads(elevations)
landslides2 = json_normalize(data[u'features'])

request=Request('http://www.oregongeology.org/arcgis/rest/services/Public/SLIDO_3_2_Historic_Points/MapServer/0/query?where=OBJECTID_1%3E2001+and+OBJECTID_1%3E3000&text=&objectIds=&time=&geometry=&geometryType=esriGeometryPoint&inSR=&spatialRel=esriSpatialRelIntersects&relationParam=&outFields=OBJECTID_1%2C+Shape%2C+REF_ID_COD%2C+UNIQUE_ID%2C+DATA_SOURC%2C+LOC_METHOD%2C+ORIG_ID%2C+SLIDE_NAME%2C+DATE%2C+LENGTH_ft%2C+WIDTH_ft%2C+DEPTH_ft%2C+SLOPE%2C+TYPE_MOVE%2C+MOVE_CLASS%2C+CONTR_FACT%2C+TYPE_MTRL%2C+AREA_ft2%2C+VOLUME_ft3%2C+DEEP_SHAL%2C+DAMAGES%2C+LOSSES%2C+COMMENTS%2C+Annual_Cos%2C+Repair_Cos&returnGeometry=false&returnTrueCurves=false&maxAllowableOffset=&geometryPrecision=&outSR=&returnIdsOnly=false&returnCountOnly=false&orderByFields=&groupByFieldsForStatistics=&outStatistics=&returnZ=false&returnM=false&gdbVersion=&returnDistinctValues=false&resultOffset=&resultRecordCount=&f=pjson')
response = urlopen(request)
elevations = response.read()
data = json.loads(elevations)
landslides3 = json_normalize(data[u'features'])

request=Request('http://www.oregongeology.org/arcgis/rest/services/Public/SLIDO_3_2_Historic_Points/MapServer/0/query?where=OBJECTID_1%3E3001+and+OBJECTID_1%3E4000&text=&objectIds=&time=&geometry=&geometryType=esriGeometryPoint&inSR=&spatialRel=esriSpatialRelIntersects&relationParam=&outFields=OBJECTID_1%2C+Shape%2C+REF_ID_COD%2C+UNIQUE_ID%2C+DATA_SOURC%2C+LOC_METHOD%2C+ORIG_ID%2C+SLIDE_NAME%2C+DATE%2C+LENGTH_ft%2C+WIDTH_ft%2C+DEPTH_ft%2C+SLOPE%2C+TYPE_MOVE%2C+MOVE_CLASS%2C+CONTR_FACT%2C+TYPE_MTRL%2C+AREA_ft2%2C+VOLUME_ft3%2C+DEEP_SHAL%2C+DAMAGES%2C+LOSSES%2C+COMMENTS%2C+Annual_Cos%2C+Repair_Cos&returnGeometry=false&returnTrueCurves=false&maxAllowableOffset=&geometryPrecision=&outSR=&returnIdsOnly=false&returnCountOnly=false&orderByFields=&groupByFieldsForStatistics=&outStatistics=&returnZ=false&returnM=false&gdbVersion=&returnDistinctValues=false&resultOffset=&resultRecordCount=&f=pjson')
response = urlopen(request)
elevations = response.read()
data = json.loads(elevations)
landslides4 = json_normalize(data[u'features'])

request=Request('http://www.oregongeology.org/arcgis/rest/services/Public/SLIDO_3_2_Historic_Points/MapServer/0/query?where=OBJECTID_1%3E4001+and+OBJECTID_1%3E5000&text=&objectIds=&time=&geometry=&geometryType=esriGeometryPoint&inSR=&spatialRel=esriSpatialRelIntersects&relationParam=&outFields=OBJECTID_1%2C+Shape%2C+REF_ID_COD%2C+UNIQUE_ID%2C+DATA_SOURC%2C+LOC_METHOD%2C+ORIG_ID%2C+SLIDE_NAME%2C+DATE%2C+LENGTH_ft%2C+WIDTH_ft%2C+DEPTH_ft%2C+SLOPE%2C+TYPE_MOVE%2C+MOVE_CLASS%2C+CONTR_FACT%2C+TYPE_MTRL%2C+AREA_ft2%2C+VOLUME_ft3%2C+DEEP_SHAL%2C+DAMAGES%2C+LOSSES%2C+COMMENTS%2C+Annual_Cos%2C+Repair_Cos&returnGeometry=false&returnTrueCurves=false&maxAllowableOffset=&geometryPrecision=&outSR=&returnIdsOnly=false&returnCountOnly=false&orderByFields=&groupByFieldsForStatistics=&outStatistics=&returnZ=false&returnM=false&gdbVersion=&returnDistinctValues=false&resultOffset=&resultRecordCount=&f=pjson')
response = urlopen(request)
elevations = response.read()
data = json.loads(elevations)
landslides5 = json_normalize(data[u'features'])

request=Request('http://www.oregongeology.org/arcgis/rest/services/Public/SLIDO_3_2_Historic_Points/MapServer/0/query?where=OBJECTID_1%3E5001+and+OBJECTID_1%3E6000&text=&objectIds=&time=&geometry=&geometryType=esriGeometryPoint&inSR=&spatialRel=esriSpatialRelIntersects&relationParam=&outFields=OBJECTID_1%2C+Shape%2C+REF_ID_COD%2C+UNIQUE_ID%2C+DATA_SOURC%2C+LOC_METHOD%2C+ORIG_ID%2C+SLIDE_NAME%2C+DATE%2C+LENGTH_ft%2C+WIDTH_ft%2C+DEPTH_ft%2C+SLOPE%2C+TYPE_MOVE%2C+MOVE_CLASS%2C+CONTR_FACT%2C+TYPE_MTRL%2C+AREA_ft2%2C+VOLUME_ft3%2C+DEEP_SHAL%2C+DAMAGES%2C+LOSSES%2C+COMMENTS%2C+Annual_Cos%2C+Repair_Cos&returnGeometry=false&returnTrueCurves=false&maxAllowableOffset=&geometryPrecision=&outSR=&returnIdsOnly=false&returnCountOnly=false&orderByFields=&groupByFieldsForStatistics=&outStatistics=&returnZ=false&returnM=false&gdbVersion=&returnDistinctValues=false&resultOffset=&resultRecordCount=&f=pjson')
response = urlopen(request)
elevations = response.read()
data = json.loads(elevations)
landslides6 = json_normalize(data[u'features'])

request=Request('http://www.oregongeology.org/arcgis/rest/services/Public/SLIDO_3_2_Historic_Points/MapServer/0/query?where=OBJECTID_1%3E6001+and+OBJECTID_1%3E7000&text=&objectIds=&time=&geometry=&geometryType=esriGeometryPoint&inSR=&spatialRel=esriSpatialRelIntersects&relationParam=&outFields=OBJECTID_1%2C+Shape%2C+REF_ID_COD%2C+UNIQUE_ID%2C+DATA_SOURC%2C+LOC_METHOD%2C+ORIG_ID%2C+SLIDE_NAME%2C+DATE%2C+LENGTH_ft%2C+WIDTH_ft%2C+DEPTH_ft%2C+SLOPE%2C+TYPE_MOVE%2C+MOVE_CLASS%2C+CONTR_FACT%2C+TYPE_MTRL%2C+AREA_ft2%2C+VOLUME_ft3%2C+DEEP_SHAL%2C+DAMAGES%2C+LOSSES%2C+COMMENTS%2C+Annual_Cos%2C+Repair_Cos&returnGeometry=false&returnTrueCurves=false&maxAllowableOffset=&geometryPrecision=&outSR=&returnIdsOnly=false&returnCountOnly=false&orderByFields=&groupByFieldsForStatistics=&outStatistics=&returnZ=false&returnM=false&gdbVersion=&returnDistinctValues=false&resultOffset=&resultRecordCount=&f=pjson')
response = urlopen(request)
elevations = response.read()
data = json.loads(elevations)
landslides7 = json_normalize(data[u'features'])

request=Request('http://www.oregongeology.org/arcgis/rest/services/Public/SLIDO_3_2_Historic_Points/MapServer/0/query?where=OBJECTID_1%3E7001+and+OBJECTID_1%3E8000&text=&objectIds=&time=&geometry=&geometryType=esriGeometryPoint&inSR=&spatialRel=esriSpatialRelIntersects&relationParam=&outFields=OBJECTID_1%2C+Shape%2C+REF_ID_COD%2C+UNIQUE_ID%2C+DATA_SOURC%2C+LOC_METHOD%2C+ORIG_ID%2C+SLIDE_NAME%2C+DATE%2C+LENGTH_ft%2C+WIDTH_ft%2C+DEPTH_ft%2C+SLOPE%2C+TYPE_MOVE%2C+MOVE_CLASS%2C+CONTR_FACT%2C+TYPE_MTRL%2C+AREA_ft2%2C+VOLUME_ft3%2C+DEEP_SHAL%2C+DAMAGES%2C+LOSSES%2C+COMMENTS%2C+Annual_Cos%2C+Repair_Cos&returnGeometry=false&returnTrueCurves=false&maxAllowableOffset=&geometryPrecision=&outSR=&returnIdsOnly=false&returnCountOnly=false&orderByFields=&groupByFieldsForStatistics=&outStatistics=&returnZ=false&returnM=false&gdbVersion=&returnDistinctValues=false&resultOffset=&resultRecordCount=&f=pjson')
response = urlopen(request)
elevations = response.read()
data = json.loads(elevations)
landslides8 = json_normalize(data[u'features'])

request=Request('http://www.oregongeology.org/arcgis/rest/services/Public/SLIDO_3_2_Historic_Points/MapServer/0/query?where=OBJECTID_1%3E8001+and+OBJECTID_1%3E9000&text=&objectIds=&time=&geometry=&geometryType=esriGeometryPoint&inSR=&spatialRel=esriSpatialRelIntersects&relationParam=&outFields=OBJECTID_1%2C+Shape%2C+REF_ID_COD%2C+UNIQUE_ID%2C+DATA_SOURC%2C+LOC_METHOD%2C+ORIG_ID%2C+SLIDE_NAME%2C+DATE%2C+LENGTH_ft%2C+WIDTH_ft%2C+DEPTH_ft%2C+SLOPE%2C+TYPE_MOVE%2C+MOVE_CLASS%2C+CONTR_FACT%2C+TYPE_MTRL%2C+AREA_ft2%2C+VOLUME_ft3%2C+DEEP_SHAL%2C+DAMAGES%2C+LOSSES%2C+COMMENTS%2C+Annual_Cos%2C+Repair_Cos&returnGeometry=false&returnTrueCurves=false&maxAllowableOffset=&geometryPrecision=&outSR=&returnIdsOnly=false&returnCountOnly=false&orderByFields=&groupByFieldsForStatistics=&outStatistics=&returnZ=false&returnM=false&gdbVersion=&returnDistinctValues=false&resultOffset=&resultRecordCount=&f=pjson')
response = urlopen(request)
elevations = response.read()
data = json.loads(elevations)
landslides9 = json_normalize(data[u'features'])

request=Request('http://www.oregongeology.org/arcgis/rest/services/Public/SLIDO_3_2_Historic_Points/MapServer/0/query?where=OBJECTID_1%3E9001+and+OBJECTID_1%3E10000&text=&objectIds=&time=&geometry=&geometryType=esriGeometryPoint&inSR=&spatialRel=esriSpatialRelIntersects&relationParam=&outFields=OBJECTID_1%2C+Shape%2C+REF_ID_COD%2C+UNIQUE_ID%2C+DATA_SOURC%2C+LOC_METHOD%2C+ORIG_ID%2C+SLIDE_NAME%2C+DATE%2C+LENGTH_ft%2C+WIDTH_ft%2C+DEPTH_ft%2C+SLOPE%2C+TYPE_MOVE%2C+MOVE_CLASS%2C+CONTR_FACT%2C+TYPE_MTRL%2C+AREA_ft2%2C+VOLUME_ft3%2C+DEEP_SHAL%2C+DAMAGES%2C+LOSSES%2C+COMMENTS%2C+Annual_Cos%2C+Repair_Cos&returnGeometry=false&returnTrueCurves=false&maxAllowableOffset=&geometryPrecision=&outSR=&returnIdsOnly=false&returnCountOnly=false&orderByFields=&groupByFieldsForStatistics=&outStatistics=&returnZ=false&returnM=false&gdbVersion=&returnDistinctValues=false&resultOffset=&resultRecordCount=&f=pjson')
response = urlopen(request)
elevations = response.read()
data = json.loads(elevations)
landslides10 = json_normalize(data[u'features'])

request=Request('http://www.oregongeology.org/arcgis/rest/services/Public/SLIDO_3_2_Historic_Points/MapServer/0/query?where=OBJECTID_1%3E10001+and+OBJECTID_1%3E11000&text=&objectIds=&time=&geometry=&geometryType=esriGeometryPoint&inSR=&spatialRel=esriSpatialRelIntersects&relationParam=&outFields=OBJECTID_1%2C+Shape%2C+REF_ID_COD%2C+UNIQUE_ID%2C+DATA_SOURC%2C+LOC_METHOD%2C+ORIG_ID%2C+SLIDE_NAME%2C+DATE%2C+LENGTH_ft%2C+WIDTH_ft%2C+DEPTH_ft%2C+SLOPE%2C+TYPE_MOVE%2C+MOVE_CLASS%2C+CONTR_FACT%2C+TYPE_MTRL%2C+AREA_ft2%2C+VOLUME_ft3%2C+DEEP_SHAL%2C+DAMAGES%2C+LOSSES%2C+COMMENTS%2C+Annual_Cos%2C+Repair_Cos&returnGeometry=false&returnTrueCurves=false&maxAllowableOffset=&geometryPrecision=&outSR=&returnIdsOnly=false&returnCountOnly=false&orderByFields=&groupByFieldsForStatistics=&outStatistics=&returnZ=false&returnM=false&gdbVersion=&returnDistinctValues=false&resultOffset=&resultRecordCount=&f=pjson')
response = urlopen(request)
elevations = response.read()
data = json.loads(elevations)
landslides11 = json_normalize(data[u'features'])

request=Request('http://www.oregongeology.org/arcgis/rest/services/Public/SLIDO_3_2_Historic_Points/MapServer/0/query?where=OBJECTID_1%3E11001+and+OBJECTID_1%3E12000&text=&objectIds=&time=&geometry=&geometryType=esriGeometryPoint&inSR=&spatialRel=esriSpatialRelIntersects&relationParam=&outFields=OBJECTID_1%2C+Shape%2C+REF_ID_COD%2C+UNIQUE_ID%2C+DATA_SOURC%2C+LOC_METHOD%2C+ORIG_ID%2C+SLIDE_NAME%2C+DATE%2C+LENGTH_ft%2C+WIDTH_ft%2C+DEPTH_ft%2C+SLOPE%2C+TYPE_MOVE%2C+MOVE_CLASS%2C+CONTR_FACT%2C+TYPE_MTRL%2C+AREA_ft2%2C+VOLUME_ft3%2C+DEEP_SHAL%2C+DAMAGES%2C+LOSSES%2C+COMMENTS%2C+Annual_Cos%2C+Repair_Cos&returnGeometry=false&returnTrueCurves=false&maxAllowableOffset=&geometryPrecision=&outSR=&returnIdsOnly=false&returnCountOnly=false&orderByFields=&groupByFieldsForStatistics=&outStatistics=&returnZ=false&returnM=false&gdbVersion=&returnDistinctValues=false&resultOffset=&resultRecordCount=&f=pjson')
response = urlopen(request)
elevations = response.read()
data = json.loads(elevations)
landslides11 = json_normalize(data[u'features'])

request=Request('http://www.oregongeology.org/arcgis/rest/services/Public/SLIDO_3_2_Historic_Points/MapServer/0/query?where=OBJECTID_1%3E12001+and+OBJECTID_1%3E12094&text=&objectIds=&time=&geometry=&geometryType=esriGeometryPoint&inSR=&spatialRel=esriSpatialRelIntersects&relationParam=&outFields=OBJECTID_1%2C+Shape%2C+REF_ID_COD%2C+UNIQUE_ID%2C+DATA_SOURC%2C+LOC_METHOD%2C+ORIG_ID%2C+SLIDE_NAME%2C+DATE%2C+LENGTH_ft%2C+WIDTH_ft%2C+DEPTH_ft%2C+SLOPE%2C+TYPE_MOVE%2C+MOVE_CLASS%2C+CONTR_FACT%2C+TYPE_MTRL%2C+AREA_ft2%2C+VOLUME_ft3%2C+DEEP_SHAL%2C+DAMAGES%2C+LOSSES%2C+COMMENTS%2C+Annual_Cos%2C+Repair_Cos&returnGeometry=false&returnTrueCurves=false&maxAllowableOffset=&geometryPrecision=&outSR=&returnIdsOnly=false&returnCountOnly=false&orderByFields=&groupByFieldsForStatistics=&outStatistics=&returnZ=false&returnM=false&gdbVersion=&returnDistinctValues=false&resultOffset=&resultRecordCount=&f=pjson')
response = urlopen(request)
elevations = response.read()
data = json.loads(elevations)
landslides12 = json_normalize(data[u'features'])

# %%
landslides1.columns = ['AREA_ft2', 'Annual_Cos',
       'COMMENTS', 'CONTR_FACT', 'DAMAGES',
       'DATA_SOURC', 'DATE', 'DEEP_SHAL',
       'DEPTH_ft', 'LENGTH_ft',
       'LOC_METHOD', 'LOSSES',
       'MOVE_CLASS', 'OBJECTID_1',
       'ORIG_ID', 'REF_ID_COD',
       'Repair_Cos', 'SLIDE_NAME', 'SLOPE',
       'TYPE_MOVE', 'TYPE_MTRL',
       'UNIQUE_ID', 'VOLUME_ft3',
       'WIDTH_ft', 'x', 'y']

landslides2.columns = ['AREA_ft2', 'Annual_Cos',
       'COMMENTS', 'CONTR_FACT', 'DAMAGES',
       'DATA_SOURC', 'DATE', 'DEEP_SHAL',
       'DEPTH_ft', 'LENGTH_ft',
       'LOC_METHOD', 'LOSSES',
       'MOVE_CLASS', 'OBJECTID_1',
       'ORIG_ID', 'REF_ID_COD',
       'Repair_Cos', 'SLIDE_NAME', 'SLOPE',
       'TYPE_MOVE', 'TYPE_MTRL',
       'UNIQUE_ID', 'VOLUME_ft3',
       'WIDTH_ft', 'x', 'y']

landslides3.columns = ['AREA_ft2', 'Annual_Cos',
       'COMMENTS', 'CONTR_FACT', 'DAMAGES',
       'DATA_SOURC', 'DATE', 'DEEP_SHAL',
       'DEPTH_ft', 'LENGTH_ft',
       'LOC_METHOD', 'LOSSES',
       'MOVE_CLASS', 'OBJECTID_1',
       'ORIG_ID', 'REF_ID_COD',
       'Repair_Cos', 'SLIDE_NAME', 'SLOPE',
       'TYPE_MOVE', 'TYPE_MTRL',
       'UNIQUE_ID', 'VOLUME_ft3',
       'WIDTH_ft', 'x', 'y']

landslides4.columns = ['AREA_ft2', 'Annual_Cos',
       'COMMENTS', 'CONTR_FACT', 'DAMAGES',
       'DATA_SOURC', 'DATE', 'DEEP_SHAL',
       'DEPTH_ft', 'LENGTH_ft',
       'LOC_METHOD', 'LOSSES',
       'MOVE_CLASS', 'OBJECTID_1',
       'ORIG_ID', 'REF_ID_COD',
       'Repair_Cos', 'SLIDE_NAME', 'SLOPE',
       'TYPE_MOVE', 'TYPE_MTRL',
       'UNIQUE_ID', 'VOLUME_ft3',
       'WIDTH_ft', 'x', 'y']

landslides5.columns = ['AREA_ft2', 'Annual_Cos',
       'COMMENTS', 'CONTR_FACT', 'DAMAGES',
       'DATA_SOURC', 'DATE', 'DEEP_SHAL',
       'DEPTH_ft', 'LENGTH_ft',
       'LOC_METHOD', 'LOSSES',
       'MOVE_CLASS', 'OBJECTID_1',
       'ORIG_ID', 'REF_ID_COD',
       'Repair_Cos', 'SLIDE_NAME', 'SLOPE',
       'TYPE_MOVE', 'TYPE_MTRL',
       'UNIQUE_ID', 'VOLUME_ft3',
       'WIDTH_ft', 'x', 'y']

landslides6.columns = ['AREA_ft2', 'Annual_Cos',
       'COMMENTS', 'CONTR_FACT', 'DAMAGES',
       'DATA_SOURC', 'DATE', 'DEEP_SHAL',
       'DEPTH_ft', 'LENGTH_ft',
       'LOC_METHOD', 'LOSSES',
       'MOVE_CLASS', 'OBJECTID_1',
       'ORIG_ID', 'REF_ID_COD',
       'Repair_Cos', 'SLIDE_NAME', 'SLOPE',
       'TYPE_MOVE', 'TYPE_MTRL',
       'UNIQUE_ID', 'VOLUME_ft3',
       'WIDTH_ft', 'x', 'y']

landslides7.columns = ['AREA_ft2', 'Annual_Cos',
       'COMMENTS', 'CONTR_FACT', 'DAMAGES',
       'DATA_SOURC', 'DATE', 'DEEP_SHAL',
       'DEPTH_ft', 'LENGTH_ft',
       'LOC_METHOD', 'LOSSES',
       'MOVE_CLASS', 'OBJECTID_1',
       'ORIG_ID', 'REF_ID_COD',
       'Repair_Cos', 'SLIDE_NAME', 'SLOPE',
       'TYPE_MOVE', 'TYPE_MTRL',
       'UNIQUE_ID', 'VOLUME_ft3',
       'WIDTH_ft', 'x', 'y']

landslides8.columns = ['AREA_ft2', 'Annual_Cos',
       'COMMENTS', 'CONTR_FACT', 'DAMAGES',
       'DATA_SOURC', 'DATE', 'DEEP_SHAL',
       'DEPTH_ft', 'LENGTH_ft',
       'LOC_METHOD', 'LOSSES',
       'MOVE_CLASS', 'OBJECTID_1',
       'ORIG_ID', 'REF_ID_COD',
       'Repair_Cos', 'SLIDE_NAME', 'SLOPE',
       'TYPE_MOVE', 'TYPE_MTRL',
       'UNIQUE_ID', 'VOLUME_ft3',
       'WIDTH_ft', 'x', 'y']

landslides9.columns = ['AREA_ft2', 'Annual_Cos',
       'COMMENTS', 'CONTR_FACT', 'DAMAGES',
       'DATA_SOURC', 'DATE', 'DEEP_SHAL',
       'DEPTH_ft', 'LENGTH_ft',
       'LOC_METHOD', 'LOSSES',
       'MOVE_CLASS', 'OBJECTID_1',
       'ORIG_ID', 'REF_ID_COD',
       'Repair_Cos', 'SLIDE_NAME', 'SLOPE',
       'TYPE_MOVE', 'TYPE_MTRL',
       'UNIQUE_ID', 'VOLUME_ft3',
       'WIDTH_ft', 'x', 'y']

landslides10.columns = ['AREA_ft2', 'Annual_Cos',
       'COMMENTS', 'CONTR_FACT', 'DAMAGES',
       'DATA_SOURC', 'DATE', 'DEEP_SHAL',
       'DEPTH_ft', 'LENGTH_ft',
       'LOC_METHOD', 'LOSSES',
       'MOVE_CLASS', 'OBJECTID_1',
       'ORIG_ID', 'REF_ID_COD',
       'Repair_Cos', 'SLIDE_NAME', 'SLOPE',
       'TYPE_MOVE', 'TYPE_MTRL',
       'UNIQUE_ID', 'VOLUME_ft3',
       'WIDTH_ft', 'x', 'y']

landslides11.columns = ['AREA_ft2', 'Annual_Cos',
       'COMMENTS', 'CONTR_FACT', 'DAMAGES',
       'DATA_SOURC', 'DATE', 'DEEP_SHAL',
       'DEPTH_ft', 'LENGTH_ft',
       'LOC_METHOD', 'LOSSES',
       'MOVE_CLASS', 'OBJECTID_1',
       'ORIG_ID', 'REF_ID_COD',
       'Repair_Cos', 'SLIDE_NAME', 'SLOPE',
       'TYPE_MOVE', 'TYPE_MTRL',
       'UNIQUE_ID', 'VOLUME_ft3',
       'WIDTH_ft', 'x', 'y']

landslides12.columns = ['AREA_ft2', 'Annual_Cos',
       'COMMENTS', 'CONTR_FACT', 'DAMAGES',
       'DATA_SOURC', 'DATE', 'DEEP_SHAL',
       'DEPTH_ft', 'LENGTH_ft',
       'LOC_METHOD', 'LOSSES',
       'MOVE_CLASS', 'OBJECTID_1',
       'ORIG_ID', 'REF_ID_COD',
       'Repair_Cos', 'SLIDE_NAME', 'SLOPE',
       'TYPE_MOVE', 'TYPE_MTRL',
       'UNIQUE_ID', 'VOLUME_ft3',
       'WIDTH_ft', 'x', 'y']

# %%
from pyproj import Proj, transform

inProj = Proj(init='epsg:3857')
outProj = Proj(init='epsg:4326')

lat = np.array(landslides1.x)
lon = np.array(landslides1.y)
x2,y2 = transform(inProj,outProj,lat,lon)
landslide1_latlon = DataFrame(np.c_[y2, x2], columns=['Lat', 'Lon'])
landslides1_new = pd.concat([landslides1, landslide1_latlon], axis=1)
#print x2,y2

lat = np.array(landslides2.x)
lon = np.array(landslides2.y)
x2,y2 = transform(inProj,outProj,lat,lon)
landslide2_latlon = DataFrame(np.c_[y2, x2], columns=['Lat', 'Lon'])
landslides2_new = pd.concat([landslides2, landslide2_latlon], axis=1)

lat = np.array(landslides3.x)
lon = np.array(landslides3.y)
x2,y2 = transform(inProj,outProj,lat,lon)
landslide3_latlon = DataFrame(np.c_[y2, x2], columns=['Lat', 'Lon'])
landslides3_new = pd.concat([landslides3, landslide3_latlon], axis=1)

lat = np.array(landslides4.x)
lon = np.array(landslides4.y)
x2,y2 = transform(inProj,outProj,lat,lon)
landslide4_latlon = DataFrame(np.c_[y2, x2], columns=['Lat', 'Lon'])
landslides4_new = pd.concat([landslides4, landslide4_latlon], axis=1)

lat = np.array(landslides5.x)
lon = np.array(landslides5.y)
x2,y2 = transform(inProj,outProj,lat,lon)
landslide5_latlon = DataFrame(np.c_[y2, x2], columns=['Lat', 'Lon'])
landslides5_new = pd.concat([landslides5, landslide5_latlon], axis=1)

lat = np.array(landslides6.x)
lon = np.array(landslides6.y)
x2,y2 = transform(inProj,outProj,lat,lon)
landslide6_latlon = DataFrame(np.c_[y2, x2], columns=['Lat', 'Lon'])
landslides6_new = pd.concat([landslides6, landslide6_latlon], axis=1)

lat = np.array(landslides7.x)
lon = np.array(landslides7.y)
x2,y2 = transform(inProj,outProj,lat,lon)
landslide7_latlon = DataFrame(np.c_[y2, x2], columns=['Lat', 'Lon'])
landslides7_new = pd.concat([landslides7, landslide7_latlon], axis=1)

lat = np.array(landslides8.x)
lon = np.array(landslides8.y)
x2,y2 = transform(inProj,outProj,lat,lon)
landslide8_latlon = DataFrame(np.c_[y2, x2], columns=['Lat', 'Lon'])
landslides8_new = pd.concat([landslides8, landslide8_latlon], axis=1)

lat = np.array(landslides9.x)
lon = np.array(landslides9.y)
x2,y2 = transform(inProj,outProj,lat,lon)
landslide9_latlon = DataFrame(np.c_[y2, x2], columns=['Lat', 'Lon'])
landslides9_new = pd.concat([landslides9, landslide9_latlon], axis=1)

lat = np.array(landslides10.x)
lon = np.array(landslides10.y)
x2,y2 = transform(inProj,outProj,lat,lon)
landslide10_latlon = DataFrame(np.c_[y2, x2], columns=['Lat', 'Lon'])
landslides10_new = pd.concat([landslides10, landslide10_latlon], axis=1)

lat = np.array(landslides11.x)
lon = np.array(landslides11.y)
x2,y2 = transform(inProj,outProj,lat,lon)
landslide11_latlon = DataFrame(np.c_[y2, x2], columns=['Lat', 'Lon'])
landslides11_new = pd.concat([landslides11, landslide11_latlon], axis=1)

lat = np.array(landslides12.x)
lon = np.array(landslides12.y)
x2,y2 = transform(inProj,outProj,lat,lon)
landslide12_latlon = DataFrame(np.c_[y2, x2], columns=['Lat', 'Lon'])
landslides12_new = pd.concat([landslides12, landslide12_latlon], axis=1)

# %%
df1 = landslides1_new.append(landslides2_new)
df2 = landslides3_new.append(landslides4_new)
df3 = landslides5_new.append(landslides6_new)
df4 = landslides7_new.append(landslides8_new)
df5 = landslides9_new.append(landslides10_new)
df6 = landslides11_new.append(landslides12_new)

df11 = df1.append(df2)
df22 = df3.append(df4)
df33 = df5.append(df6)

df111 = df11.append(df22)
landslides_final = df111.append(df33)

# %%
from mpl_toolkits.basemap import Basemap
import matplotlib.pyplot as plt
import numpy as np

#my_map = Basemap(projection='ortho',lon_0=-105,lat_0=40,resolution='l')

# make sure the value of resolution is a lowercase L,
#  for 'low', not a numeral 1
#my_map = Basemap(projection='ortho', lat_0=50, lon_0=-100,
#             resolution='l', area_thresh=500)

my_map = Basemap(llcrnrlon=-125, llcrnrlat=41, urcrnrlon=-115,
     urcrnrlat=47, projection='tmerc', lat_1=33, lat_2=45,
     lon_0=-119, lat_0=45, resolution='h', area_thresh=10000)

my_map.drawcoastlines()
my_map.drawcountries()
my_map.fillcontinents(color='coral')

lon = np.array(landslides_final.Lon)
lat = np.array(landslides_final.Lat)
y,x = my_map(lon, lat)
my_map.plot(y,x, 'ro', markersize=4)

plt.show()
# Out:
# <img src="data:image/png;base64,...">

# %%
landslides_final
# Out:
#     AREA_ft2  Annual_Cos                                           COMMENTS  \
# 0          0     165.230   Hwy Name:Heppner; Hwy Number:052;Mile Post:34...
# 1          0     146.570   Hwy Name:Heppner; Hwy Number:052;Mile Post:44...
# 2          0       0.000   Hwy Name:Shaniko-Fossil; Hwy Number:291;Mile ...
# 3          0       0.000   Hwy Name:Shaniko-Fossil; Hwy Number:291;Mile ...
# 4          0       0.000   Hwy Name:Pacific Hwy. East; Hwy Number:081;Mi...
# 5          0       0.000   Hwy Name:Shaniko-Fossil; Hwy Number:291;Mile ...
# 6          0       0.000   Hwy Name:Shaniko-Fossil; Hwy Number:291;Mile ...
# 7          0       0.000   Hwy Name:Shaniko-Fossil; Hwy Number:291;Mile ...
# 8          0       0.000   Hwy Name:Shaniko-Fossil; Hwy Number:291;Mile ...
# 9          0       0.000   Hwy Name:Shaniko-Fossil; Hwy Number:291;Mile ...
# 10         0       0.000   Hwy Name:Shaniko-Fossil; Hwy Number:291;Mile ...
# 11         0       0.000   Hwy Name:Shaniko-Fossil; Hwy Number:291;Mile ...
# 12         0       0.000   Hwy Name:Shaniko-Fossil; Hwy Number:291;Mile ...
# 13         0       0.000   Hwy Name:Shaniko-Fossil; Hwy Number:291;Mile ...
# 14         0       0.000   Hwy Name:Shaniko-Fossil; Hwy Number:291;Mile ...
# 15         0       0.000   Hwy Name:Shaniko-Fossil; Hwy Number:291;Mile ...
# 16         0       0.000   Hwy Name:Shaniko-Fossil; Hwy Number:291;Mile ...
# 17         0       0.000   Hwy Name:Shaniko-Fossil; Hwy Number:291;Mile ...
# 18         0       0.000   Hwy Name:Shaniko-Fossil; Hwy Number:291;Mile ...
# 19         0     218.050   Hwy Name:Antelope; Hwy Number:293;Mile Post:1...
# 20         0     218.050   Hwy Name:Antelope; Hwy Number:300;Mile Post:1...
# 21         0     349.585   Hwy Name:Antelope; Hwy Number:293;Mile Post:3...
# 22         0     338.330   Hwy Name:Antelope; Hwy Number:293;Mile Post:3...
# 23         0     447.355   Hwy Name:Antelope; Hwy Number:293;Mile Post:3...
# 24         0    1330.810   Hwy Name:Antelope; Hwy Number:293;Mile Post:4...
# 25         0     218.050   Hwy Name:Antelope; Hwy Number:293;Mile Post:4...
# 26         0     109.025   Hwy Name:Antelope; Hwy Number:293;Mile Post:4...
# 27         0     109.025   Hwy Name:Antelope; Hwy Number:293;Mile Post:5...
# 28         0     109.025   Hwy Name:Antelope; Hwy Number:293;Mile Post:5...
# 29         0     109.025   Hwy Name:Antelope; Hwy Number:293;Mile Post:5...
# ..       ...         ...                                                ...
# 66    555883       0.000
# 67    555778       0.000
# 68    555223       0.000
# 69    553686       0.000
# 70    549472       0.000
# 71    548526       0.000
# 72    507899       0.000
# 73    555172       0.000
# 74       NaN         NaN                                               None
# 75         0       0.000                       Closed for at least 6 months
# 76         0       0.000                                      1 lane closed
# 77         0       0.000                                       Lane Closure
# 78         0       0.000
# 79         0       0.000
# 80         0       0.000
# 81         0       0.000  2 lanes closed I-84E; 1 Lane closed I-84W; car...
# 82         0       0.000                                        road closed
# 83         0       0.000
# 84         0       0.000                                        road closed
# 85         0       0.000
# 86         0       0.000
# 87         0       0.000
# 88         0       0.000
# 89         0       0.000
# 90         0       0.000
# 91         0       0.000
# 92         0       0.000                                        Road closed
# 93         0       0.000
# 94         0       0.000  closed hwy columbia river highay for a couple ...
# 0          0       0.000  closed hwy columbia river highay for a couple ...
#
#           CONTR_FACT                                            DAMAGES  \
# 0                           Road Impact:RF on roadway;Lanes Affected:1;
# 1                           Road Impact:RF on roadway;Lanes Affected:1;
# 2                           Road Impact:RF on roadway;Lanes Affected:1;
# 3                           Road Impact:RF on roadway;Lanes Affected:1;
# 4                                     Road Impact:RF no ditch enter rd;
# 5                           Road Impact:RF on roadway;Lanes Affected:1;
# 6                           Road Impact:RF on roadway;Lanes Affected:1;
# 7                           Road Impact:RF on roadway;Lanes Affected:1;
# 8                           Road Impact:RF on roadway;Lanes Affected:1;
# 9                           Road Impact:RF on roadway;Lanes Affected:1;
# 10                          Road Impact:RF on roadway;Lanes Affected:1;
# 11                          Road Impact:RF on roadway;Lanes Affected:1;
# 12                          Road Impact:RF on roadway;Lanes Affected:1;
# 13                          Road Impact:RF on roadway;Lanes Affected:1;
# 14                          Road Impact:RF on roadway;Lanes Affected:1;
# 15                          Road Impact:RF on roadway;Lanes Affected:1;
# 16                          Road Impact:RF on roadway;Lanes Affected:1;
# 17                          Road Impact:RF on roadway;Lanes Affected:1;
# 18                          Road Impact:RF on roadway;Lanes Affected:1;
# 19                          Road Impact:RF on roadway;Lanes Affected:1;
# 20                          Road Impact:RF on roadway;Lanes Affected:1;
# 21                          Road Impact:RF on roadway;Lanes Affected:1;
# 22                          Road Impact:RF on roadway;Lanes Affected:1;
# 23                    Road Impact:RF no ditch enter rd;Lanes Affecte...
# 24                          Road Impact:RF on roadway;Lanes Affected:2;
# 25                          Road Impact:RF on roadway;Lanes Affected:1;
# 26                          Road Impact:RF on roadway;Lanes Affected:1;
# 27                          Road Impact:RF on roadway;Lanes Affected:1;
# 28                          Road Impact:RF on roadway;Lanes Affected:1;
# 29                          Road Impact:RF on roadway;Lanes Affected:1;
# ..               ...                                                ...
# 66           Natural
# 67           Natural
# 68           Natural
# 69  Recent Clear cut
# 70  Recent Clear cut
# 71           Natural
# 72           Natural
# 73           Natural
# 74              None                                               None
# 75                                              Historic Bridge Damaged
# 76
# 77
# 78
# 79
# 80
# 81
# 82
# 83
# 84
# 85                                                car crash and flipped
# 86
# 87
# 88
# 89
# 90
# 91
# 92
# 93         Cut slope                                     2 cars crashed
# 94
# 0
#
#                              DATA_SOURC        DATE DEEP_SHAL  DEPTH_ft  \
# 0   Oregon Department of Transportation  12/10/2008                   0
# 1   Oregon Department of Transportation  12/10/2008                   0
# 2   Oregon Department of Transportation   12/9/2008                   0
# 3   Oregon Department of Transportation   12/9/2008                   0
# 4   Oregon Department of Transportation   5/11/2009                   0
# 5   Oregon Department of Transportation   12/9/2008                   0
# 6   Oregon Department of Transportation   12/9/2008                   0
# 7   Oregon Department of Transportation   12/9/2008                   0
# 8   Oregon Department of Transportation   12/9/2008                   0
# 9   Oregon Department of Transportation   12/9/2008                   0
# 10  Oregon Department of Transportation   12/9/2008                   0
# 11  Oregon Department of Transportation   12/9/2008                   0
# 12  Oregon Department of Transportation   12/9/2008                   0
# 13  Oregon Department of Transportation   12/9/2008                   0
# 14  Oregon Department of Transportation   12/9/2008                   0
# 15  Oregon Department of Transportation   12/9/2008                   0
# 16  Oregon Department of Transportation   12/9/2008                   0
# 17  Oregon Department of Transportation   12/9/2008                   0
# 18  Oregon Department of Transportation   12/9/2008                   0
# 19  Oregon Department of Transportation   12/9/2008                   0
# 20  Oregon Department of Transportation   12/9/2008                   0
# 21  Oregon Department of Transportation   12/9/2008                   0
# 22  Oregon Department of Transportation   12/9/2008                   0
# 23  Oregon Department of Transportation   12/9/2008                   0
# 24  Oregon Department of Transportation   12/9/2008                   0
# 25  Oregon Department of Transportation   12/9/2008                   0
# 26  Oregon Department of Transportation   12/9/2008                   0
# 27  Oregon Department of Transportation   12/9/2008                   0
# 28  Oregon Department of Transportation   12/9/2008                   0
# 29  Oregon Department of Transportation   12/9/2008                   0
# ..                                  ...         ...       ...       ...
# 66                                        2005-2009                   0
# 67                                        2005-2009                   0
# 68                                        2005-2009                   0
# 69                                        2005-2009                   0
# 70                                        2005-2009                   0
# 71                                        2005-2009                   0
# 72                                        2005-2009                   0
# 73                                        2005-2009                   0
# 74                                 None  01/16/1974      None       NaN
# 75                                 News  01/09/2014                   0
# 76                      ODOT Trip Check  12/22/2013                   0
# 77                                 News  01/12/2014                   0
# 78                                 News  02/10/2014                   0
# 79                 ODOT Trip Check/News     2/12/14                   0
# 80                      ODOT Trip Check     2/12/14                   0
# 81                                 News     2/12/14                   0
# 82                                 News     2/14/14                   0
# 83                      ODOT Trip Check     2/14/14                   0
# 84                      ODOT Trip Check     2/14/14                   0
# 85                              TV News   2/15/2014                   0
# 86                      ODOT Trip check        2014                   0
# 87                      ODOT Trip Check   2/15/2014                   0
# 88                      ODOT Trip Check   2/15/2014                   0
# 89                      ODOT TRip Check   2/15/2014                   0
# 90                            Oregonian   2/25/2014                   0
# 91            ODOT TRip Check/Oregonian        2014                   0
# 92                      ODOT Trip Check   2/28/2014                   0
# 93                                 News   3/05/2014                   0
# 94                              TV News  06/05/2014                   0
# 0                               TV News  06/05/2014                   0
#
#     LENGTH_ft     ...        SLOPE   TYPE_MOVE              TYPE_MTRL  \
# 0           0     ...       0.0000
# 1           0     ...       0.0000
# 2           0     ...       0.0000
# 3           0     ...       0.0000
# 4           0     ...       0.0000
# 5           0     ...       0.0000
# 6           0     ...       0.0000
# 7           0     ...       0.0000
# 8           0     ...       0.0000
# 9           0     ...       0.0000
# 10          0     ...       0.0000
# 11          0     ...       0.0000
# 12          0     ...       0.0000
# 13          0     ...       0.0000
# 14          0     ...       0.0000
# 15          0     ...       0.0000
# 16          0     ...       0.0000
# 17          0     ...       0.0000
# 18          0     ...       0.0000
# 19          0     ...       0.0000
# 20          0     ...       0.0000
# 21          0     ...       0.0000
# 22          0     ...       0.0000
# 23          0     ...       0.0000
# 24          0     ...       0.0000
# 25          0     ...       0.0000
# 26          0     ...       0.0000
# 27          0     ...       0.0000
# 28          0     ...       0.0000
# 29          0     ...       0.0000
# ..        ...     ...          ...         ...                    ...
# 66        160     ...      25.1192         EFL  Coast Range Volcanics
# 67         95     ...      32.5862         EFL  Coast Range Volcanics
# 68        105     ...      39.5188         EFL  Coast Range Volcanics
# 69        220     ...      35.6152         EFL  Coast Range Volcanics
# 70        130     ...      34.9188         DFL  Coast Range Volcanics
# 71        200     ...      34.5137         EFL  Coast Range Volcanics
# 72         80     ...      14.7334         EFL  Coast Range Volcanics
# 73        100     ...      37.1740         EFL  Coast Range Volcanics
# 74        NaN     ...          NaN        None                   None
# 75          0     ...       0.0000        Fall
# 76          0     ...       0.0000
# 77         10     ...       0.0000        Fall
# 78          0     ...       0.0000        Flow
# 79          0     ...       0.0000
# 80          0     ...       0.0000
# 81          0     ...       0.0000
# 82          0     ...       0.0000
# 83          0     ...       0.0000
# 84          0     ...       0.0000
# 85          0     ...       0.0000
# 86          0     ...       0.0000
# 87          0     ...       0.0000        rock
# 88          0     ...       0.0000
# 89          0     ...       0.0000
# 90          0     ...       0.0000
# 91          0     ...       0.0000
# 92          0     ...       0.0000
# 93          0     ...       0.0000  Rock Slide
# 94          0     ...       0.0000        fall
# 0           0     ...       0.0000        fall
#
#              UNIQUE_ID VOLUME_ft3 WIDTH_ft             x        y        Lat  \
# 0              LS_1000          0        0 -1.332711e+07  5694664  45.462721
# 1              LS_1001          0        0 -1.331014e+07  5679651  45.368054
# 2              LS_1002          0        0  -1.34353e+07  5607241  44.909218
# 3              LS_1003          0        0 -1.340282e+07  5607513  44.910951
# 4              LS_1004          0        0 -1.364933e+07  5677064  45.351721
# 5              LS_1005          0        0 -1.340148e+07  5607919  44.913530
# 6              LS_1006          0        0 -1.339817e+07  5606995  44.907653
# 7              LS_1007          0        0  -1.33979e+07  5606912  44.907123
# 8              LS_1008          0        0 -1.339744e+07  5606871  44.906862
# 9              LS_1009          0        0 -1.339674e+07  5606617  44.905246
# 10             LS_1010          0        0 -1.339603e+07  5606302  44.903242
# 11             LS_1011          0        0 -1.339472e+07  5606158  44.902325
# 12             LS_1012          0        0 -1.339425e+07  5605931  44.900883
# 13             LS_1013          0        0 -1.339246e+07  5606288  44.903155
# 14             LS_1014          0        0 -1.339184e+07  5606135  44.902182
# 15             LS_1015          0        0 -1.339002e+07  5606429  44.904051
# 16             LS_1016          0        0 -1.338887e+07  5607167  44.908745
# 17             LS_1017          0        0 -1.338865e+07  5607730  44.912331
# 18             LS_1018          0        0 -1.338756e+07  5609418  44.923067
# 19             LS_1019          0        0 -1.346088e+07  5594772  44.829837
# 20             LS_1020          0        0 -1.346092e+07  5595195  44.832531
# 21             LS_1021          0        0 -1.345813e+07  5597007  44.844074
# 22             LS_1022          0        0 -1.345749e+07  5597052  44.844361
# 23             LS_1023          0        0 -1.345695e+07  5597131  44.844858
# 24             LS_1024          0        0 -1.345591e+07  5597545  44.847498
# 25             LS_1025          0        0 -1.345567e+07  5597474  44.847043
# 26             LS_1026          0        0 -1.345549e+07  5597597  44.847829
# 27             LS_1027          0        0 -1.345468e+07  5598471  44.853394
# 28             LS_1028          0        0 -1.345384e+07  5599094  44.857361
# 29             LS_1029          0        0 -1.345371e+07  5599198  44.858025
# ..                 ...        ...      ...           ...      ...        ...
# 66            LS_12066          0       90 -1.374324e+07  5722357  45.636933
# 67            LS_12067          0       70  -1.37433e+07  5722592  45.638409
# 68            LS_12068          0       60 -1.374357e+07  5723502  45.644123
# 69            LS_12069          0       90  -1.37443e+07  5725167  45.654580
# 70            LS_12070          0       40 -1.374631e+07  5730019  45.685038
# 71            LS_12071          0       50 -1.374681e+07  5732222  45.698860
# 72            LS_12072          0       35 -1.376249e+07  5679019  45.364066
# 73            LS_12073          0       70 -1.374361e+07  5723868  45.646423
# 74                None        NaN      NaN -1.372165e+07  5298553  42.911775
# 75   MickKAunpub2014_0          0        0 -1.359391e+07  5712765  45.576654
# 76   MickKAunpub2014_1          0        0 -1.371775e+07  5799431  46.118945
# 77   MickKAunpub2014_2          0       10 -1.353439e+07  5733437  45.706480
# 78   MickKAunpub2014_3          0        0  -1.36553e+07  5685151  45.402750
# 79   MickKAunpub2014_4          0        0 -1.378232e+07  5569175  44.666529
# 80   MickKAunpub2014_5          0        0 -1.365641e+07  5260460  42.660646
# 81   MickKAunpub2014_6          0        0 -1.353359e+07  5733453  45.706581
# 82   MickKAunpub2014_7          0        0 -1.366119e+07  5705216  45.529165
# 83   MickKAunpub2014_8          0        0 -1.381158e+07  5418356  43.694954
# 84   MickKAunpub2014_9          0        0 -1.383872e+07  5187628  42.177652
# 85  MickKAunpub2014_10          0        0 -1.367081e+07  5719329  45.617912
# 86  MickKAunpub2014_11          0        0 -1.381993e+07  5432577  43.787245
# 87  MickKAunpub2014_12          0        0 -1.378162e+07  5306490  42.963978
# 88  MickKAunpub2014_13          0        0 -1.378825e+07  5412548  43.657215
# 89  MickKAunpub2014_14          0        0  -1.36769e+07  5358442  43.304541
# 90  MickKAunpub2014_15          0        0 -1.363708e+07  5686031  45.408301
# 91  MickKAunpub2014_16          0        0 -1.362204e+07  5704252  45.523096
# 92  MickKAunpub2014_17          0        0 -1.377778e+07  5526106  44.390713
# 93  MickKAunpub2014_18          0        0 -1.366637e+07  5713560  45.581649
# 94  MickKAunpub2014_19          0        0  -1.36212e+07  5703132  45.516047
# 0   MickKAunpub2014_19          0        0  -1.36212e+07  5703132  45.516047
#
#            Lon
# 0  -119.719422
# 1  -119.567066
# 2  -120.691329
# 3  -120.399547
# 4  -122.614023
# 5  -120.387564
# 6  -120.357837
# 7  -120.355396
# 8  -120.351259
# 9  -120.344949
# 10 -120.338571
# 11 -120.326780
# 12 -120.322622
# 13 -120.306535
# 14 -120.300971
# 15 -120.284622
# 16 -120.274301
# 17 -120.272279
# 18 -120.262539
# 19 -120.921170
# 20 -120.921476
# 21 -120.896438
# 22 -120.890699
# 23 -120.885803
# 24 -120.876459
# 25 -120.874360
# 26 -120.872700
# 27 -120.865424
# 28 -120.857934
# 29 -120.856716
# ..         ...
# 66 -123.457658
# 67 -123.458141
# 68 -123.460608
# 69 -123.467158
# 70 -123.485228
# 71 -123.489651
# 72 -123.630521
# 73 -123.460925
# 74 -123.263712
# 75 -122.116205
# 76 -123.228620
# 77 -121.581479
# 78 -122.667640
# 79 -123.808719
# 80 -122.677653
# 81 -121.574296
# 82 -122.720562
# 83 -124.071574
# 84 -124.315341
# 85 -122.806989
# 86 -124.146574
# 87 -123.802440
# 88 -123.861946
# 89 -122.861651
# 90 -122.503975
# 91 -122.368888
# 92 -123.767898
# 93 -122.767049
# 94 -122.361342
# 0  -122.361342
#
# [10096 rows x 28 columns]
